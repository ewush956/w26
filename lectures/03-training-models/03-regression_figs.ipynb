# %% [markdown]
# # Training models
# This notebook is adapted from the [Chapter 4 notebook](https://github.com/ageron/handson-ml3/blob/main/04_training_linear_models.ipynb) of the textbook.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42) # to make this code example reproducible
m = 100 # number of instances
x = 2 * np.random.rand(m, 1) # column vector

# actual theta_0 = 4, theta_1 = 3
y = 4 + 3 * x + np.random.randn(m, 1) # another column vector

plt.scatter(x, y)

plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.savefig("../figures/03-noisy_line_plot.png")

# %%
# A fairly random range of theta values
t0 = np.linspace(2, 6, m)
t1 = np.linspace(1, 4, m)
T0, T1 = np.meshgrid(t0, t1)

# calculate the MSE for each combo
MSE = np.zeros(T0.shape)
for i in range(m):
    for j in range(m):
        MSE[i, j] = ((y - (T0[i, j] + T1[i, j] * x)) ** 2).mean()

# Plot the surface
fig = plt.figure(figsize=(10, 4))

# MSE vs T0
ax1 = fig.add_subplot(131)
ax1.plot(t0, MSE.mean(axis=0))
ax1.set_xlabel(r"$\theta_0$")
ax1.set_ylabel("MSE")
ax1.set_title("MSE vs $\Theta_0$")

# MSE vs T1
ax2 = fig.add_subplot(132)
ax2.plot(t1, MSE.mean(axis=1))
ax2.set_xlabel(r"$\theta_1$")
ax2.set_ylabel("MSE")
ax2.set_title("MSE vs $\Theta_1$")

# 3D projection of MSE vs T0 and T1
ax3 = fig.add_subplot(133, projection='3d')
ax3.plot_surface(T0, T1, MSE, cmap='viridis')
ax3.set_xlabel(r"$\theta_0$")
ax3.set_ylabel(r"$\theta_1$")
ax3.set_zlabel("MSE")
ax3.set_title("MSE vs $\Theta_0$ and $\Theta_1$")

plt.tight_layout()
plt.savefig("../figures/03-cost-surface.png")
plt.show()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\T'
# <>:27: SyntaxWarning: invalid escape sequence '\T'
# <>:35: SyntaxWarning: invalid escape sequence '\T'
# <>:20: SyntaxWarning: invalid escape sequence '\T'
# <>:27: SyntaxWarning: invalid escape sequence '\T'
# <>:35: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\ccurtis\AppData\Local\Temp\ipykernel_5840\3870974193.py:20: SyntaxWarning: invalid escape sequence '\T'
#   ax1.set_title("MSE vs $\Theta_0$")
# C:\Users\ccurtis\AppData\Local\Temp\ipykernel_5840\3870974193.py:27: SyntaxWarning: invalid escape sequence '\T'
#   ax2.set_title("MSE vs $\Theta_1$")
# C:\Users\ccurtis\AppData\Local\Temp\ipykernel_5840\3870974193.py:35: SyntaxWarning: invalid escape sequence '\T'
#   ax3.set_title("MSE vs $\Theta_0$ and $\Theta_1$")

# %%
mu_x = x.sum() / m
mu_y = y.sum() / m

theta_1 = (mu_y * x.sum() - (y * x).sum()) / (mu_x * x.sum() - (x * x).sum())
theta_0 = mu_y - theta_1 * mu_x
print(theta_0, theta_1)
# Out:
# 4.2150961575467445 2.770113386438486

# %%
plt.scatter(x, y)
plt.plot(x, theta_0 + theta_1 * x, "r-", label="Best fit line")
plt.plot(x, 4 + 3 * x, "g-", label="True line")

plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.savefig("../figures/03-best_fit_line.png")

# %%
# Matrix implementation
X = np.hstack([np.ones((m, 1)), x])  # add x0 = 1 to each instance

theta_best = np.linalg.inv(X.T @ X) @ X.T @ y
print(theta_best)
print(X)
# Out:
# [[4.21509616]
#  [2.77011339]]
# [[1.         0.74908024]
#  [1.         1.90142861]
#  [1.         1.46398788]
#  [1.         1.19731697]
#  [1.         0.31203728]
#  [1.         0.31198904]
#  [1.         0.11616722]
#  [1.         1.73235229]
#  [1.         1.20223002]
#  [1.         1.41614516]
#  [1.         0.04116899]
#  [1.         1.9398197 ]
#  [1.         1.66488528]
#  [1.         0.42467822]
#  [1.         0.36364993]
#  [1.         0.36680902]
#  [1.         0.60848449]
#  [1.         1.04951286]
#  [1.         0.86389004]
#  [1.         0.58245828]
#  [1.         1.22370579]
#  [1.         0.27898772]
#  [1.         0.5842893 ]
#  [1.         0.73272369]
#  [1.         0.91213997]
#  [1.         1.57035192]
#  [1.         0.39934756]
#  [1.         1.02846888]
#  [1.         1.18482914]
#  [1.         0.09290083]
#  [1.         1.2150897 ]
#  [1.         0.34104825]
#  [1.         0.13010319]
#  [1.         1.89777107]
#  [1.         1.93126407]
#  [1.         1.6167947 ]
#  [1.         0.60922754]
#  [1.         0.19534423]
#  [1.         1.36846605]
#  [1.         0.88030499]
#  [1.         0.24407647]
#  [1.         0.99035382]
#  [1.         0.06877704]
#  [1.         1.8186408 ]
#  [1.         0.51755996]
#  [1.         1.32504457]
#  [1.         0.62342215]
#  [1.         1.04013604]
#  [1.         1.09342056]
#  [1.         0.36970891]
#  [1.         1.93916926]
#  [1.         1.55026565]
#  [1.         1.87899788]
#  [1.         1.7896547 ]
#  [1.         1.19579996]
#  [1.         1.84374847]
#  [1.         0.176985  ]
#  [1.         0.39196572]
#  [1.         0.09045458]
#  [1.         0.65066066]
#  [1.         0.77735458]
#  [1.         0.54269806]
#  [1.         1.65747502]
#  [1.         0.71350665]
#  [1.         0.56186902]
#  [1.         1.08539217]
#  [1.         0.28184845]
#  [1.         1.60439396]
#  [1.         0.14910129]
#  [1.         1.97377387]
#  [1.         1.54448954]
#  [1.         0.39743136]
#  [1.         0.01104423]
#  [1.         1.63092286]
#  [1.         1.41371469]
#  [1.         1.45801434]
#  [1.         1.54254069]
#  [1.         0.1480893 ]
#  [1.         0.71693146]
#  [1.         0.23173812]
#  [1.         1.72620685]
#  [1.         1.24659625]
#  [1.         0.66179605]
#  [1.         0.1271167 ]
#  [1.         0.62196464]
#  [1.         0.65036664]
#  [1.         1.45921236]
#  [1.         1.27511494]
#  [1.         1.77442549]
#  [1.         0.94442985]
#  [1.         0.23918849]
#  [1.         1.42648957]
#  [1.         1.5215701 ]
#  [1.         1.1225544 ]
#  [1.         1.54193436]
#  [1.         0.98759119]
#  [1.         1.04546566]
#  [1.         0.85508204]
#  [1.         0.05083825]
#  [1.         0.21578285]]

# %%
# Gradient Descent: Batch version
np.random.seed(42)
def gradient(X, y, theta):
    return 2 / X.shape[0] * X.T @ (X @ theta - y)

eta = 0.1  # learning rate
n_iterations = 100
theta_batch = np.zeros((n_iterations, 2))
theta = np.random.randn(2, 1)  # random initialization

for i in range(n_iterations):
    theta = theta - eta * gradient(X, y, theta)
    theta_batch[i] = theta.T

batch_best = theta

# %%
batch_best
# Out:
# array([[4.19463891],
#        [2.78817602]])

# %%
# Stochastic Gradient Descent
n_epochs = 50
t0, t1 = 5, 50  # learning schedule hyperparameters

def learning_schedule(t):
    return t0 / (t + t1)

theta = np.random.randn(2, 1)  # random initialization
# just for visualization purposes
theta_sgd = np.zeros((n_epochs * m, 2))

for epoch in range(n_epochs):
    for i in range(m):
        random_index = np.random.randint(m)
        xi = X[random_index : random_index + 1]
        yi = y[random_index : random_index + 1]
        gradients = gradient(xi, yi, theta)
        eta = learning_schedule(epoch * m + i)
        theta = theta - eta * gradients
        theta_sgd[epoch * m + i] = theta.T

sgd_best = theta

# %%
sgd_best
# Out:
# array([[4.20742938],
#        [2.74264448]])

# %%
# Mini-batch Gradient Descent

n_epochs = 50
minibatch_size = 20
n_batches_per_epoch = m // minibatch_size

np.random.seed(42)
theta = np.random.randn(2, 1)  # random initialization
theta_mgd = np.zeros((n_epochs * n_batches_per_epoch, 2))

for epoch in range(n_epochs):
    shuffled_indices = np.random.permutation(m)
    X_shuffled = X[shuffled_indices]
    y_shuffled = y[shuffled_indices]
    for i in range(n_batches_per_epoch):
        xi = X_shuffled[i * minibatch_size : (i + 1) * minibatch_size]
        yi = y_shuffled[i * minibatch_size : (i + 1) * minibatch_size]
        gradients = gradient(xi, yi, theta)
        eta = learning_schedule(epoch * n_batches_per_epoch + i)
        theta = theta - eta * gradients
        theta_mgd[epoch * n_batches_per_epoch + i] = theta.T

mgd_best = theta

# %%
plt.plot(theta_batch[:, 0], theta_batch[:, 1], "b.-", label="Batch gradient descent")
plt.plot(theta_sgd[:, 0], theta_sgd[:, 1], "r.-", label="Stochastic gradient descent")
plt.plot(theta_mgd[:, 0], theta_mgd[:, 1], "g.-", label="Mini-batch gradient descent")
plt.xlabel(r"$\theta_0$")
plt.ylabel(r"$\theta_1$")
plt.scatter(batch_best[0], batch_best[1], color='k', marker='x', label='Batch Final value', zorder=10)
plt.scatter(sgd_best[0], sgd_best[1], edgecolors='k', facecolors='none', marker='o', label='SGD Final value', zorder=10)
plt.scatter(mgd_best[0], mgd_best[1], edgecolors='k', facecolors='none', marker='s', label='Mini-batch Final value', zorder=10)
plt.scatter(theta_best[0], theta_best[1], color='k', marker='*', label='Analytic value', zorder=10, s=100)
plt.legend()
plt.grid(True)
plt.axis([2.6, 4.6, 2.3, 3.4])
plt.savefig("../figures/03-gradient_descent_comparison.png")

# %%
# Illustration of early stopping
from copy import deepcopy
from sklearn.metrics import root_mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import SGDRegressor

# extra code – creates the same quadratic dataset as earlier and splits it
np.random.seed(42)
m = 100
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X ** 2 + X + 2 + np.random.randn(m, 1)
X_train, y_train = X[: m // 2], y[: m // 2, 0]
X_valid, y_valid = X[m // 2 :], y[m // 2 :, 0]

preprocessing =Pipeline([
    ("Poly Features", PolynomialFeatures(degree=90, include_bias=False)),
     ("Scaler", StandardScaler())
     ])


X_train_prep = preprocessing.fit_transform(X_train)
X_valid_prep = preprocessing.transform(X_valid)
sgd_reg = SGDRegressor(penalty=None, eta0=0.002, random_state=42)
n_epochs = 500
best_valid_rmse = float('inf')
train_errors, val_errors = [], []  # extra code – it's for the figure below

for epoch in range(n_epochs):
    sgd_reg.partial_fit(X_train_prep, y_train)
    y_valid_predict = sgd_reg.predict(X_valid_prep)
    val_error = root_mean_squared_error(y_valid, y_valid_predict)
    if val_error < best_valid_rmse:
        best_valid_rmse = val_error
        best_model = deepcopy(sgd_reg)

    # extra code – we evaluate the train error and save it for the figure
    y_train_predict = sgd_reg.predict(X_train_prep)
    train_error = root_mean_squared_error(y_train, y_train_predict)
    val_errors.append(val_error)
    train_errors.append(train_error)

# extra code – this section generates and saves Figure 4–20
best_epoch = np.argmin(val_errors)
plt.figure(figsize=(6, 4))
plt.annotate('Best model',
             xy=(best_epoch, best_valid_rmse),
             xytext=(best_epoch, best_valid_rmse + 0.5),
             ha="center",
             arrowprops=dict(facecolor='black', shrink=0.05))
plt.plot([0, n_epochs], [best_valid_rmse, best_valid_rmse], "k:", linewidth=2)
plt.plot(val_errors, "b-", linewidth=3, label="Validation set")
plt.plot(best_epoch, best_valid_rmse, "bo")
plt.plot(train_errors, "r--", linewidth=2, label="Training set")
plt.legend(loc="upper right")
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.axis([0, n_epochs, 0, 3.5])
plt.grid()

plt.savefig("../figures/03-early_stopping.png")
